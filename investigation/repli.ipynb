# %%
import mne
import numpy as np
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
edf_path = r'D:\2025_26_internship\bigP3BCI_pipeline\src\data\StudyA\A_01\SE001\Test\CB\A_01_SE001_CB_Test06.edf'


# Load the EDF file
raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)

# # Print info to verify
# print(raw.info)
# print(raw.annotations)  # Check stimuli markers; P300 datasets use event codes for row/column flashes

# # Select only EEG channels (exclude EOG, etc., if present)
# eeg_picks = mne.pick_types(raw.info, meg=False, eeg=True, stim=False, eog=False)
# raw.pick(picks=eeg_picks)
# Out:
# C:\Users\qigan\AppData\Local\Temp\ipykernel_7044\3164919141.py:10: RuntimeWarning: Channels contain different highpass filters. Highest filter setting will be stored.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# C:\Users\qigan\AppData\Local\Temp\ipykernel_7044\3164919141.py:10: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)

# %%
len(raw)
# Out:
# 35208

# %%
raw.n_times
# Out:
# np.int64(35208)

# %%
sb = raw.copy().pick(["StimulusBegin"]).get_data().ravel()
st = raw.copy().pick(["StimulusType"]).get_data().ravel()
print(f"Length of sb: {len(sb)}, Length of st: {len(st)}")
onsets = np.where((sb[:-1]<0.5)&(sb[1:]>=0.5))[0]+1
# Out:
# Length of sb: 35208, Length of st: 35208
